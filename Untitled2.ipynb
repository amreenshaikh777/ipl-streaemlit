# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None)

# %%
df=pd.read_csv(r"C:\Users\Ganji Bhaskar\Videos\ipl\IPL_Matches_2008_2022.csv")

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  29-05-2022     2022        Final
# 1    1312199   Ahmedabad  27-05-2022     2022  Qualifier 2
# 2    1312198     Kolkata  25-05-2022     2022   Eliminator
# 3    1312197     Kolkata  24-05-2022     2022  Qualifier 1
# 4    1304116      Mumbai  22-05-2022     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  20-04-2008  2007/08            4
# 946   335985      Mumbai  20-04-2008  2007/08            5
# 947   335984       Delhi  19-04-2008  2007/08            3
# 948   335983  Chandigarh  19-04-2008  2007/08            2
# 949   335982   Bangalore  18-04-2008  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df["count"]=1

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  29-05-2022     2022        Final
# 1    1312199   Ahmedabad  27-05-2022     2022  Qualifier 2
# 2    1312198     Kolkata  25-05-2022     2022   Eliminator
# 3    1312197     Kolkata  24-05-2022     2022  Qualifier 1
# 4    1304116      Mumbai  22-05-2022     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  20-04-2008  2007/08            4
# 946   335985      Mumbai  20-04-2008  2007/08            5
# 947   335984       Delhi  19-04-2008  2007/08            3
# 948   335983  Chandigarh  19-04-2008  2007/08            2
# 949   335982   Bangalore  18-04-2008  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.groupby(["TossWinner","TossDecision"])["count"].sum().reset_index()
# Out:
#                      TossWinner TossDecision  count
# 0           Chennai Super Kings          bat     55
# 1           Chennai Super Kings        field     54
# 2               Deccan Chargers          bat     24
# 3               Deccan Chargers        field     19
# 4                Delhi Capitals          bat      8
# 5                Delhi Capitals        field     28
# 6              Delhi Daredevils          bat     29
# 7              Delhi Daredevils        field     51
# 8                 Gujarat Lions          bat      1
# 9                 Gujarat Lions        field     14
# 10               Gujarat Titans          bat      4
# 11               Gujarat Titans        field      6
# 12              Kings XI Punjab          bat     27
# 13              Kings XI Punjab        field     58
# 14         Kochi Tuskers Kerala          bat      3
# 15         Kochi Tuskers Kerala        field      5
# 16        Kolkata Knight Riders          bat     36
# ...

# %%
df.groupby(["Venue","TossDecision"])["count"].sum().reset_index()
# Out:
#                                Venue TossDecision  count
# 0               Arun Jaitley Stadium          bat      6
# 1               Arun Jaitley Stadium        field      8
# 2        Arun Jaitley Stadium, Delhi          bat      1
# 3        Arun Jaitley Stadium, Delhi        field      3
# 4                   Barabati Stadium          bat      2
# ..                               ...          ...    ...
# 89                  Wankhede Stadium        field     51
# 90          Wankhede Stadium, Mumbai          bat      7
# 91          Wankhede Stadium, Mumbai        field     24
# 92  Zayed Cricket Stadium, Abu Dhabi          bat      3
# 93  Zayed Cricket Stadium, Abu Dhabi        field      5
#
# [94 rows x 3 columns]

# %%
stadium_name={"ACA-VDCA Stadium":"Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium",
              "M. A. Chidambaram Stadium":"MA Chidambaram Stadium, Chepauk",
             "M Chinnaswamy Stadium":"M. Chinnaswamy Stadium",
             "Feroz Shah Kotla Ground":"Arun Jaitley Cricket Stadium",
             "Feroz Shah Kotla":"Arun Jaitley Cricket Stadium",
             "Rajiv Gandhi Intl. Cricket Stadium":"Rajiv Gandhi International Stadium, Uppal",
             "Subrata Roy Sahara Stadium":"Maharashtra Cricket Association Stadium",
             "Punjab Cricket Association IS Bindra Stadium, Mohali":"Punjab Cricket Association Stadium, Mohali",
              "Sardar Patel Stadium, Motera":"Narendra Modi Stadium",
              "IS Bindra Stadium":"Punjab Cricket Association Stadium, Mohali",
              "Wankhede Stadium, Mumbai":"Wankhede Stadium",
              "Dr DY Patil Sports Academy":"Dr DY Patil Sports Academy, Mumbai",
              "M.Chinnaswamy Stadium":"M. Chinnaswamy Stadium",
              "Rajiv Gandhi International Stadium":"Rajiv Gandhi International Stadium, Uppal",
              "Arun Jaitley Stadium":"Arun Jaitley Cricket Stadium",
              "Maharashtra Cricket Association Stadium, Pune":"Maharashtra Cricket Association Stadium",
              "MA Chidambaram Stadium, Chepauk, Chennai":"MA Chidambaram Stadium, Chepauk",
              "Brabourne Stadium":"Brabourne Stadium, Mumbai",
              "MA Chidambaram Stadium":"MA Chidambaram Stadium, Chepauk",
              "Narendra Modi Stadium, Ahmedabad":"Narendra Modi Stadium",
              "Arun Jaitley Stadium, Delhi":"Arun Jaitley Cricket Stadium",
              "Eden Gardens, Kolkata":"Eden Gardens"       
             }

# %%
df["Venue"]= df["Venue"].map(lambda x: stadium_name[x] if x in stadium_name else x)

# %%
df["Team1"].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
team_names={"Delhi Daredevils":"Delhi Capitals",
            "Kings XI Punjab":"Punjab Kings",
            "Rising Pune Supergiants":"Rising Pune Supergiant",
            "Kings XI Punjab":"Punjab Kings",
            
           }

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  29-05-2022     2022        Final
# 1    1312199   Ahmedabad  27-05-2022     2022  Qualifier 2
# 2    1312198     Kolkata  25-05-2022     2022   Eliminator
# 3    1312197     Kolkata  24-05-2022     2022  Qualifier 1
# 4    1304116      Mumbai  22-05-2022     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  20-04-2008  2007/08            4
# 946   335985      Mumbai  20-04-2008  2007/08            5
# 947   335984       Delhi  19-04-2008  2007/08            3
# 948   335983  Chandigarh  19-04-2008  2007/08            2
# 949   335982   Bangalore  18-04-2008  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df["Team2"] = df["Team2"].map(lambda x: team_names[x] if x in team_names else x)
df["Team1"] = df["Team1"].map(lambda x: team_names[x] if x in team_names else x)
df["TossWinner"]=df["TossWinner"].map(lambda x: team_names[x] if x in team_names else x)
df["WinningTeam"]=df["WinningTeam"].map(lambda x: team_names[x] if x in team_names else x)

# %%
df["City"].value_counts()
# Out:
# City
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Dharamsala          9
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Port Elizabeth      7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  29-05-2022     2022        Final
# 1    1312199   Ahmedabad  27-05-2022     2022  Qualifier 2
# 2    1312198     Kolkata  25-05-2022     2022   Eliminator
# 3    1312197     Kolkata  24-05-2022     2022  Qualifier 1
# 4    1304116      Mumbai  22-05-2022     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  20-04-2008  2007/08            4
# 946   335985      Mumbai  20-04-2008  2007/08            5
# 947   335984       Delhi  19-04-2008  2007/08            3
# 948   335983  Chandigarh  19-04-2008  2007/08            2
# 949   335982   Bangalore  18-04-2008  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df1=pd.read_csv(r"C:\Users\Ganji Bhaskar\Videos\ipl\IPL_Ball_by_Ball_2008_2022.csv")

# %%
data=pd.merge(df1,df,on="ID",how="inner")

# %%
with_result=data[data["WinningTeam"].notna()]

# %%
df["Player_of_Match"].value_counts().reset_index()
# Out:
#     Player_of_Match  count
# 0    AB de Villiers     25
# 1          CH Gayle     22
# 2         DA Warner     18
# 3         RG Sharma     18
# 4          MS Dhoni     17
# ..              ...    ...
# 257   CR Brathwaite      1
# 258     Mohsin Khan      1
# 259         A Zampa      1
# 260     BCJ Cutting      1
# 261     MF Maharoof      1
#
# [262 rows x 2 columns]

# %%
df["Venue"].value_counts().reset_index()
# Out:
#                                                 Venue  count
# 0                                    Wankhede Stadium    104
# 1                              M. Chinnaswamy Stadium     80
# 2                                        Eden Gardens     79
# 3                        Arun Jaitley Cricket Stadium     78
# 4                     MA Chidambaram Stadium, Chepauk     67
# 5           Rajiv Gandhi International Stadium, Uppal     64
# 6             Maharashtra Cricket Association Stadium     51
# 7                              Sawai Mansingh Stadium     47
# 8                 Dubai International Cricket Stadium     46
# 9          Punjab Cricket Association Stadium, Mohali     46
# 10                 Dr DY Patil Sports Academy, Mumbai     37
# 11                               Sheikh Zayed Stadium     29
# 12                            Sharjah Cricket Stadium     28
# 13                          Brabourne Stadium, Mumbai     27
# ...

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  29-05-2022     2022        Final
# 1    1312199   Ahmedabad  27-05-2022     2022  Qualifier 2
# 2    1312198     Kolkata  25-05-2022     2022   Eliminator
# 3    1312197     Kolkata  24-05-2022     2022  Qualifier 1
# 4    1304116      Mumbai  22-05-2022     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  20-04-2008  2007/08            4
# 946   335985      Mumbai  20-04-2008  2007/08            5
# 947   335984       Delhi  19-04-2008  2007/08            3
# 948   335983  Chandigarh  19-04-2008  2007/08            2
# 949   335982   Bangalore  18-04-2008  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...
